# %%
import pandas as pd
import numpy as np

data = pd.read_csv('data.csv', encoding='cp949')
data
# Out:
#          지점  지점명          일시  평균기온(°C)  최저기온(°C)  최고기온(°C)  일강수량(mm)  \
# 0        90   속초  2018-05-01      13.4       9.3      18.4       0.6
# 1        90   속초  2018-05-02       9.7       5.5      13.5      16.6
# 2        90   속초  2018-05-03      11.0       5.2      15.2       0.6
# 3        90   속초  2018-05-04      18.1      11.8      23.4       NaN
# 4        90   속초  2018-05-05      22.2      16.1      27.1       NaN
# ...     ...  ...         ...       ...       ...       ...       ...
# 250385  296  북부산  2025-06-26      24.1      18.5      30.5       NaN
# 250386  296  북부산  2025-06-27      26.3      20.6      31.2       NaN
# 250387  296  북부산  2025-06-28      26.8      21.9      31.3       NaN
# 250388  296  북부산  2025-06-29      27.6      23.4      31.5       NaN
# 250389  296  북부산  2025-06-30      27.6      23.1      31.5       NaN
#
#         평균 풍속(m/s)  평균 상대습도(%)  합계 3시간 신적설(cm)  평균 지면온도(°C)
# 0              1.2        85.1             NaN         18.5
# ...

# %%
data.isna
